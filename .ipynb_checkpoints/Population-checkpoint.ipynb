# %% [markdown]
# # World Population #
#
# Two basic questions over a country population?
#
# 1. Exist a typical population size for a country?
#
# 1. Exist a fuction that could explain the population distribution of the countries?
#
# 2. Exist some outliers in the population system?

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
from scipy import stats

# %% [markdown]
# ## Dataset from Kaggle ##
#
# [Countries of the World](https://www.kaggle.com/fernandol/countries-of-the-world) Data compiled from US Government 1970-2017 Fernando Lasso
#  •  updated 9 months ago (Version 1)

# %%
countries = pd.read_csv('countries of the world.csv')

# %%
population = countries['Population']

# %%
population = np.sort(population)

# %%
plt.plot(population, '+')
plt.title('Population')
plt.xlabel('Country (One)')
plt.ylabel('People (One))')
plt.grid(True)

# %%
plt.semilogy(population, '+')
plt.title('Population')
plt.xlabel('Country (one)')
plt.ylabel('log(People) (one)')
plt.grid(True)

# %%
plt.plot(np.cumsum(population))
plt.title('Accumulated Population')
plt.xlabel('Country')
plt.ylabel('People')
plt.grid(True)

# %%
log_population = np.log10(population)

# %%
x = np.arange(0, 227)
y = log_population

# %%
m, c = np.polyfit(x[100:170], y[100:170], 1)
print('Linear Regresion {0:2.3f} x + {1:2.3f}'.format(m,c))
# Out:
# Linear Regresion 0.009 x + 5.677

# %%
a1 = 10
a2 = 90
gradient, intercept, r_value, p_value, std_err = stats.linregress(x[a1:a2],y[a1:a2])
mn=np.min(x[a1:a2])-10
mx=np.max(x[a1:a2])+20
x1=np.linspace(mn,mx,500)
y1=gradient*x1+intercept
print('Linear Regresion {0:2.3f} x + {1:2.3f} ({2:2.3f})'.format(gradient, intercept, r_value))
# Out:
# Linear Regresion 0.025 x + 4.228 (0.998)

# %%
a1 = 90
a2 = 215
gradient, intercept, r_value, p_value, std_err = stats.linregress(x[a1:a2],y[a1:a2])
mn=np.min(x[a1:a2])-20
mx=np.max(x[a1:a2])
x2=np.linspace(mn,mx,500)
y2=gradient*x2+intercept
print('Linear Regresion {0:2.3f} x + {1:2.3f} ({2:2.3f})'.format(gradient, intercept, r_value))
# Out:
# Linear Regresion 0.011 x + 5.411 (0.992)

# %%
plt.plot(x,y,'+b')
plt.plot(x1,y1,'-r')
plt.plot(x2,y2,'-r')
plt.xlabel('Country (one)')
plt.ylabel('log10(People) (one)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ouliers ##
#
# What countries could be considered outliers?

# %%
countries.sort_values(by='Population')[215:]
# Out:
#             Country                               Region  Population  \
# 162    Philippines         ASIA (EX. NEAR EAST)             89468677
# 135         Mexico               LATIN AMER. & CARIB       107449525
# 103          Japan         ASIA (EX. NEAR EAST)            127463611
# 152        Nigeria   SUB-SAHARAN AFRICA                    131859731
# 169         Russia                  C.W. OF IND. STATES    142893540
# 16      Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 156       Pakistan         ASIA (EX. NEAR EAST)            165803560
# 27          Brazil               LATIN AMER. & CARIB       188078227
# 95       Indonesia         ASIA (EX. NEAR EAST)            245452739
# 214  United States   NORTHERN AMERICA                      298444215
# 94           India         ASIA (EX. NEAR EAST)           1095351995
# 42           China         ASIA (EX. NEAR EAST)           1313973713
#
# ...

# %% [markdown]
# ![Countries and Dependencies by population in 2014, based on data from The World Factbook.](/images/Countries_by_Population_in_2014.png)

# %% [markdown]
# ## Turning points ##
#
# Where a placed the turning points? What countries a placed on the transition area?

# %% [markdown]
# The firts inflexion point is located in populations of the range [2.0, 3.6] Milion, from Slovenia to Albania.
#
#
# The second inflexion point or outliers are placed at 100 Milion (Philippines)

# %%
countries.sort_values(by='Population')[81:99]
# Out:
#                    Country                               Region  Population  \
# 186              Slovenia   EASTERN EUROPE                          2010347
# 116               Lesotho   SUB-SAHARAN AFRICA                      2022331
# 143               Namibia   SUB-SAHARAN AFRICA                      2044147
# 123             Macedonia   EASTERN EUROPE                          2050554
# 114                Latvia   BALTICS                                 2274735
# 23                 Bhutan         ASIA (EX. NEAR EAST)              2279723
# 111                Kuwait   NEAR EAST                               2418393
# 222             West Bank   NEAR EAST                               2460492
# 212  United Arab Emirates   NEAR EAST                               2602713
# 102               Jamaica               LATIN AMER. & CARIB         2758124
# 139              Mongolia         ASIA (EX. NEAR EAST)              2832224
# ...

# %% [markdown]
# ## Considering the "Procés" ##
#
# Where will be placed an effective Cataln Republic?

# %%
countries.sort_values(by='Population')[125:135]
# Out:
#           Country                               Region  Population  \
# 100       Israel   NEAR EAST                               6352117
# 113         Laos         ASIA (EX. NEAR EAST)              6368481
# 160     Paraguay               LATIN AMER. & CARIB         6506464
# 61   El Salvador               LATIN AMER. & CARIB         6822378
# 91     Hong Kong         ASIA (EX. NEAR EAST)              6940432
# 199   Tajikistan                  C.W. OF IND. STATES      7320815
# 90      Honduras               LATIN AMER. & CARIB         7326496
# 30      Bulgaria   EASTERN EUROPE                          7385367
# 196  Switzerland   WESTERN EUROPE                          7523934
# 21         Benin   SUB-SAHARAN AFRICA                      7862944
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 100           20770                      305,8                         1,31
# ...

# %% [markdown]
# Proclaimed República Catalunya (population 7.543.825 [idescat](https://www.idescat.cat/pub/?id=aec&n=245)) should be placed as Switzerland neighbor with a population of 7.523.934

# %%
plt.plot(x,y,'+b')
plt.plot(x[134], y[134], '+r')
plt.plot(165, np.log10(14180000), '*y')
plt.title('Switzerland and The Netherlands localization')
plt.xlabel('Country (one)')
plt.ylabel('log10(People) (one)')
plt.annotate('Switzerland (7.523.934)', xy=(134, y[134]-0.45))
plt.annotate('The Netherlands (16.491.461)', xy=(168, y[168]-0.45))
plt.grid(True)
plt.show()

# %% [markdown]
# Utopic "Països Catalans" Federation should be placed as The Netherlands neighbor with a population of 14.180.000 (2016) ([Nationalia](https://www.nationalia.cat/fitxa/35/paisos-catalans))
