# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# $x^3 + 0.5 x^2 + 4 x + 10

# %%
p = np.poly1d([1, .5, 4, 10])

# %%
x = np.arange(-10, 10, .5)

# %%
plt.plot(x, p(x))
plt.grid(True)
plt.show()
